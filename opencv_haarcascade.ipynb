# %%
import cv2

import matplotlib.pyplot as plt

from google.colab.patches import cv2_imshow

# %%
face_cascade = cv2.CascadeClassifier('/content/opencv/data/haarcascades/haarcascade_frontalface_alt.xml')
image = cv2.imread('/content/daenerys.jpeg')

# %%
plt.imshow(gray)

# %%
faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)

# %%
# !git clone https://github.com/opencv/opencv.git
# Out:
# Cloning into 'opencv'...
# remote: Enumerating objects: 322564, done.
# remote: Counting objects: 100% (1330/1330), done.
# remote: Compressing objects: 100% (810/810), done.
# remote: Total 322564 (delta 683), reused 905 (delta 479), pack-reused 321234
# Receiving objects: 100% (322564/322564), 511.55 MiB | 13.83 MiB/s, done.
# Resolving deltas: 100% (224500/224500), done.
# Updating files: 100% (7218/7218), done.

# %%
img = cv2.imread('daenerys.jpeg')
if img is not None:
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
else:
    print("Image not loaded correctly.")

# %%
for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0, 0, 255), 2)

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=640x640>

# %%
eye_cascade = cv2.CascadeClassifier('/content/opencv/data/haarcascades/haarcascade_eye.xml')

# %%
eyes = eye_cascade.detectMultiScale(image)

# %%
for (x, y, w, h) in eyes:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 2)

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=640x640>
